# %%
import pandas as pd

# %%
path = "/Users/lucasderr/Desktop/city_data/cities.csv"

# %%
cities = pd.read_csv(path)

# %%
cities = cities[cities["country_name"] == "Netherlands"]

# %%
cities
# Out:
#            id            name  state_id state_code state_name  country_id  \
# 76937  150050   Boven Bolivia      2624        BQ1    Bonaire         156
# 76938  150051  Dorp Tera Kora      2624        BQ1    Bonaire         156
# 76939  150052      Oranjestad      2624        BQ1    Bonaire         156
# 76940  150053          Rincon      2624        BQ1    Bonaire         156
# 76941  150054       St. Johns      2624        BQ1    Bonaire         156
# ...       ...             ...       ...        ...        ...         ...
# 78585   78977  Wolphaartsdijk      2620         ZE    Zeeland         156
# 78586   78989         Yerseke      2620         ZE    Zeeland         156
# 78587   78992        Zaamslag      2620         ZE    Zeeland         156
# 78588   79013       Zierikzee      2620         ZE    Zeeland         156
# 78589   79020      Zoutelande      2620         ZE    Zeeland         156
#
#       country_code country_name   latitude  longitude wikiDataId
# ...

# %%
cols = ["name", 
        "latitude",
        "longitude",
        "state_name",
       ]
cities = cities[cols]

# %%
cities[cities["name"] == "Utrecht"]
# Out:
#           name  latitude  longitude state_name
# 78515  Utrecht  52.09083    5.12222    Utrecht

# %%
import seaborn as sns

sns.barplot(x="city", y="population",data=cities.head(6))
# Out:
# <AxesSubplot:xlabel='city', ylabel='population'>

# %%
18,908,608.0
